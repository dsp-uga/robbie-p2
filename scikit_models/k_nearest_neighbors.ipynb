# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import datetime
import os

# %%
def csv_to_pandas_dataframe(filename):
    data = pd.read_csv(filename,header=0)
    data = data.dropna()
    data.drop(data.columns[[0,1,2,3,4,5,6,7,8]], axis=1, inplace=True)
    return data

# %%
onlyfiles = next(os.walk('./results'))[2] 
file_count = len(onlyfiles) - 2

# %%
def create_tar_archive():
    tar_filename = "p2_" + str(file_count) +".tar"
    print(tar_filename)
    # !cd results/ && tar cvf {tar_filename} y*.txt

# %%
# X_small_train.csv
# X_small_test.csv
# X_train.csv
# Xa_test.csv, Xb_test.csv, Xc_test.csv

# %%
# train_dataframe = csv_to_pandas_dataframe('https://storage.googleapis.com/uga-dsp/project2/files/X_small_train.csv')
train_dataframe = csv_to_pandas_dataframe('https://storage.googleapis.com/uga-dsp/project2/files/X_train.csv')
X_train = train_dataframe.drop('Sex (subj)',axis=1)
y_train = train_dataframe['Sex (subj)']

# %%
test_dataframe = csv_to_pandas_dataframe('https://storage.googleapis.com/uga-dsp/project2/files/Xa_test.csv')
# X_test = test_dataframe.drop('Sex (subj)',axis=1)
# y_test = test_dataframe['Sex (subj)']
# test_dataframe
# len(test_dataframe)

# %%
test_dataframe
# Out:
#           x1     y1     x2     y2     x3     y3     x4     y4     x5     y5  \
# 0      151.0  143.0  150.0  152.0  150.0  160.0  150.0  169.0  152.0  177.0
# 1       58.0  151.0   60.0  172.0   63.0  193.0   67.0  213.0   74.0  231.0
# 2      344.0   54.0  345.0   63.0  345.0   72.0  347.0   81.0  350.0   88.0
# 3      273.0  126.0  270.0  157.0  271.0  187.0  274.0  219.0  280.0  251.0
# 4      205.0  159.0  206.0  170.0  206.0  180.0  208.0  190.0  212.0  200.0
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 45253  188.0  184.0  193.0  199.0  198.0  213.0  203.0  226.0  210.0  239.0
# 45254  271.0  177.0  271.0  183.0  271.0  190.0  272.0  197.0  274.0  203.0
# 45255  146.0  187.0  151.0  211.0  157.0  233.0  163.0  255.0  172.0  276.0
# 45256  175.0  155.0  176.0  162.0  178.0  169.0  180.0  175.0  183.0  182.0
# 45257  105.0  189.0  107.0  202.0  109.0  215.0  112.0  228.0  118.0  239.0
#
#        ...     fs2     fc1     fc2     fc3     fc4     fc5     fc6     fc7  \
# 0      ...  0.0070 -0.0557  0.0035 -0.0111 -0.2326 -0.0081 -0.0334 -0.0186
# 1      ...  0.0171 -0.0793  0.0463 -0.0023 -0.2298 -0.0129 -0.0211 -0.2370
# 2      ... -0.0007 -0.5121 -0.0080 -0.0134 -0.2127 -0.0038 -0.0159 -0.4047
# 3      ...  0.0107 -0.0727 -0.0062 -0.0065 -0.1904 -0.0142 -0.0074 -0.0315
# 4      ... -0.0029 -0.0522  0.0223 -0.0058 -0.2026 -0.0123 -0.0410 -0.0072
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 45253  ...  0.0179 -0.1334  0.0642 -0.0209 -0.0917 -0.0251 -0.0490 -0.0029
# 45254  ...  0.0138 -0.0711  0.0457 -0.0094 -0.1269 -0.0186 -0.0167 -0.0241
# 45255  ...  0.1185 -0.0995  0.0697  0.0192 -0.1076 -0.0232 -0.0297 -0.0528
# 45256  ...  0.0172 -0.0893  0.0156 -0.0092 -0.0997 -0.0248 -0.0202  0.0002
# 45257  ...  0.0111 -0.0877  0.0353  0.0024 -0.1030 -0.0065 -0.0161 -0.0975
#
#           fc8     fc9
# 0     -0.0007 -0.0061
# 1     -0.0121  0.0068
# 2      0.0062 -0.0138
# 3     -0.0024 -0.0001
# 4      0.0015 -0.0006
# ...       ...     ...
# 45253  0.0043 -0.0050
# 45254  0.0042 -0.0090
# 45255  0.0241  0.0373
# 45256 -0.0019  0.0040
# 45257  0.0072 -0.0193
#
# [45258 rows x 175 columns]

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# prediction = []
# for i in range(len(test_dataframe)):
#     p = knn.predict(test_dataframe[i])
#     prediction.append(p[0])

# # y_pred = logreg.predict(test_dataframe)
# # type(y_pred)
# # y_pred_list = y_pred.tolist()
# prediction

# %%
print(datetime.datetime.now())
# Out:
# 2021-03-17 23:37:47.999871

# %%
output = knn.predict(test_dataframe)

# %%
print(datetime.datetime.now())
# Out:
# 2021-03-17 23:40:37.180209

# %%
output_list = output.tolist()
len(output_list)
# Out:
# 45258

# %%
with open('results/ya.txt', 'w') as f:
    for item in output_list:
        f.write("%s\n" % item)

# %%
create_tar_archive()
# Out:
# p2_7.tar
# a ya.txt
# a yb.txt
# a yc.txt

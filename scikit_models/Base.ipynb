# %%
from pyspark import SparkContext, SparkConf
import pandas as pd
from operator import add

# %%
spark = SparkSession \
    .builder \
    .appName("Ethical Facial Recognition") \
    .getOrCreate()

# %%
file_name = "X_small_test.csv"
# file_path = 'https://storage.googleapis.com/uga-dsp/project2/files/' + file_name
file_path = 'dataset/' + file_name
# print(file_path)

# %%
df = spark.read.format('csv') \
                .option('header',True) \
                .option('multiLine', True) \
                .load(file_path)
panda_df = df.toPandas()

# %%
panda_df.drop(panda_df.columns[[0,1,2,3,4,5,6,7,8]], axis=1, inplace=True)
panda_df
# Out:
#         x1     y1     x2     y2     x3     y3     x4     y4     x5     y5  \
# 0    178.0  126.0  179.0  137.0  180.0  147.0  182.0  157.0  186.0  166.0
# 1    154.0  149.0  157.0  158.0  159.0  167.0  161.0  176.0  164.0  184.0
# 2    317.0  135.0  318.0  156.0  320.0  176.0  324.0  196.0  333.0  214.0
# 3    165.0  158.0  165.0  167.0  165.0  174.0  166.0  182.0  167.0  190.0
# 4    125.0  172.0  126.0  183.0  127.0  192.0  129.0  202.0  131.0  211.0
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 258   98.0  154.0  101.0  160.0  104.0  166.0  107.0  172.0  111.0  177.0
# 259  210.0  106.0  208.0  127.0  207.0  150.0  209.0  174.0  214.0  196.0
# 260  185.0  142.0  187.0  152.0  190.0  161.0  193.0  170.0  197.0  178.0
# 261  144.0   91.0  141.0   99.0  139.0  108.0  137.0  117.0  136.0  126.0
# 262  133.0  137.0  132.0  145.0  131.0  153.0  130.0  162.0  131.0  171.0
#
#      ...      fc1                   fc2      fc3      fc4      fc5      fc6  \
# ...

# %%
panda_df.head(5)
# Out:
#       x1     y1     x2     y2     x3     y3     x4     y4     x5     y5  ...  \
# 0  178.0  126.0  179.0  137.0  180.0  147.0  182.0  157.0  186.0  166.0  ...
# 1  154.0  149.0  157.0  158.0  159.0  167.0  161.0  176.0  164.0  184.0  ...
# 2  317.0  135.0  318.0  156.0  320.0  176.0  324.0  196.0  333.0  214.0  ...
# 3  165.0  158.0  165.0  167.0  165.0  174.0  166.0  182.0  167.0  190.0  ...
# 4  125.0  172.0  126.0  183.0  127.0  192.0  129.0  202.0  131.0  211.0  ...
#
#        fc1                   fc2      fc3      fc4      fc5      fc6      fc7  \
# 0  -0.0108               -0.0252  -0.0307  -0.2466  -0.0171  -0.0245  -0.0465
# 1  -0.2105                0.0102   0.0055   -0.503    -0.01  -0.0006  -0.3122
# 2   0.0001               -0.0015  -0.0098  -0.1621  -0.0258  -0.0278  -0.0173
# 3  -0.0667                0.0365   0.0029  -0.1392  -0.0368  -0.0364  -0.1145
# 4  -0.0493  0.036000000000000004  -0.0092  -0.1548   0.0062  -0.0135  -0.1543
#
#        fc8      fc9 Sex (subj)
# ...

# %%
# %store panda_df
# Out:
# Stored 'panda_df' (DataFrame)

# %%
sc.stop()
